# %%
import pandas as pd 
import numpy as np

data = pd.read_csv(r'C:\Users\Lucas\Documents\GitHub\Examen-Estadisticas\Datos\GRD_PUBLICO_2023.csv',sep='|',engine='python',encoding='utf-16')
data
# Out:
#          COD_HOSPITAL CIP_ENCRIPTADO    SEXO FECHA_NACIMIENTO ETNIA  \
# 0              122100       72196813  HOMBRE       1980-04-13  OTRO
# 1              114101    DESCONOCIDO  HOMBRE       2001-11-04  OTRO
# 2              114101       97627974  HOMBRE       2020-07-30  OTRO
# 3              106103       67770674   MUJER       1978-11-14  OTRO
# 4              106103      100390800   MUJER       2023-12-20  OTRO
# ...               ...            ...     ...              ...   ...
# 1039582        105102       78111817   MUJER       1995-12-06  OTRO
# 1039583        118100       76593606   MUJER       1991-04-26  OTRO
# 1039584        115100      100360940  HOMBRE       2015-01-08  OTRO
# 1039585        123100       78557002  HOMBRE       2014-01-07  OTRO
# 1039586        129100       70505660  HOMBRE       1950-08-24  OTRO
#
#            PROVINCIA       COMUNA                          NACIONALIDAD  \
# 0           VALDIVIA  PANGUIPULLI                                 CHILE
# ...
